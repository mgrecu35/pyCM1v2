# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# Open the CM1 output file
with nc.Dataset('cm1out.nc') as f:
   
    qr = f.variables['qr'][:]

plt.pcolormesh(qr[-1,:,10,:],cmap='jet',norm=matplotlib.colors.LogNorm(vmin=0.00001,vmax=0.006))
plt.colorbar()
